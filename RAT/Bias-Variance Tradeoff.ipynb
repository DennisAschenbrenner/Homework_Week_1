# %%
#########################################################
################# Bias-Variance-Tradeoff ################
#########################################################

# The Bias-Variance Tradeoff is fundamental for Data Science!
# It is the area where variance and bias are both low, but not the lowest 
# Both, variance and bias are errors in predicting, so it is necessery to hold them both low as far as possible 

# The B-V-Tradeoff depends on model complexity. If the model is very simple then the variance is very low but 
# the bias is extremely high. If the model is very complex with an overfitting then bias would go against zero but 
# the variance error would rise. Therefore the Bias-Variance-Tradeoff becomes extremely important to produce the 
# smallest error as possible. 

# Dimensionality reduction helps to prevent overfitting and so high variance by decreasing the complexity of
# the model.

# The optimal model complexity is shown in the picture below. 

# The total error is the sum of biased error and the variance-error

# %% [markdown]
# ![9000c0e50e1a97d0d12e85dc93affa5f.png](attachment:9000c0e50e1a97d0d12e85dc93affa5f.png)
